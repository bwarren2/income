# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/warrenb/.virtualenvs/datascience/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
years = pd.read_excel('data/median_income_by_state.xls')[3:4].T[1:]
len(years)
years = years.reset_index()

years = years[[3]]
len(years)

years_off = years.shift(1)
len(years_off)

foo = pd.concat([years_off, years], axis=1)
foo
# Out:
#                 3              3
# 0             NaN           2016
# 1            2016            NaN
# 2             NaN           2015
# 3            2015            NaN
# 4             NaN           2014
# 5            2014            NaN
# 6             NaN      2013 (39)
# 7       2013 (39)            NaN
# 8             NaN      2013 (38)
# 9       2013 (38)            NaN
# 10            NaN           2012
# 11           2012            NaN
# 12            NaN           2011
# 13           2011            NaN
# 14            NaN      2010 (37)
# 15      2010 (37)            NaN
# 16            NaN      2009 (36)
# 17      2009 (36)            NaN
# 18            NaN           2008
# 19           2008            NaN
# 20            NaN           2007
# 21           2007            NaN
# 22            NaN           2006
# 23           2006            NaN
# 24            NaN           2005
# 25           2005            NaN
# 26            NaN  2004(revised)
# ...

# %%
df.head(10)
# Out:
#   Table with row headers in column A and column headers in rows 5 and 6, and 60 and 61  \
# 3                                              State
# 4                                                NaN
#
#        Unnamed: 1       Unnamed: 2      Unnamed: 3       Unnamed: 4  \
# 3            2016              NaN            2015              NaN
# 4  Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
#
#        Unnamed: 5       Unnamed: 6      Unnamed: 7       Unnamed: 8  \
# 3            2014              NaN       2013 (39)              NaN
# 4  Median\nincome  Standard\nerror  Median\nincome  Standard\nerror
#
#        Unnamed: 9       ...            Unnamed: 59      Unnamed: 60  \
# 3       2013 (38)       ...                   1988              NaN
# 4  Median\nincome       ...         Median\nincome  Standard\nerror
#
#       Unnamed: 61      Unnamed: 62     Unnamed: 63      Unnamed: 64  \
# 3       1987 (21)              NaN            1986              NaN
# ...
